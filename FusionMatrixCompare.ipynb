# %%
import pandas

# %%
df1 = pandas.read_csv("results/reannotated_allfusions_binmx.tsv", sep="\t", index_col=0)

# %%
df2 = pandas.read_csv("results/reannotated_allfusions_binmx_v2.tsv", sep="\t", index_col=0)

# %%
df1.shape
# Out:
# (80880, 810)

# %%
df2.shape
# Out:
# (113336, 1077)

# %%
sum(df1['A549_1.7269246'])
# Out:
# 54

# %%
sum(df2['A549_1.7269246'])
# Out:
# 54

# %%
df1.columns.difference(df2.columns)
# Out:
# Index(['A549_3.9609498', 'A549_3.9609499', 'A549_4.8040408', 'A549_5.9609498',
#        'A549_5.9609499', 'A549_5.truth', 'HCC1143_3.8040408',
#        'HCC1143_3.9609499', 'HCC1143_3.truth', 'HCC1143_4.9609498',
#        'HCC1143_5A1.9609499', 'HCC1143_5B2.9609499', 'JurkatI92_1.9609499',
#        'JurkatI92_2.truth', 'JurkatI92_3.9609498', 'JurkatI92_4.9609498',
#        'JurkatI92_4.9609499', 'LNCapFGC_1.9609498', 'LNCapFGC_2.8040408',
#        'LNCapFGC_2.9609499', 'LNCapFGC_3.8040408', 'LNCapFGC_3.9609499',
#        'LNCapFGC_4.truth', 'PC3_2.9609498', 'PC3_3.9609498', 'PC3_3.9609499',
#        'PC3_5.truth', 'PC9_1.8040408', 'PC9_1.truth', 'PC9_2.8040408',
#        'PC9_2.9609498', 'PC9_3.9609499', 'giab.7185743', 'giab.7269246',
#        'giab.7378934', 'giab.7488045', 'giab.7997358', 'giab.8040408',
#        'giab.8071387', 'giab.8114525', 'giab.8281648', 'giab.8644608',
#        'giab.9609147', 'giab.9609148', 'giab.9610021', 'giab.9610272'],
#       dtype='object')

# %%
df1[ df1['JurkatI92_2.truth'] == 1 ]
# Out:
#                                                     A549_1.7269246  \
# chr11_5275511_5275532_-_chr19_36034231_36034268_+                0
# chr12_14840875_14840896_+_chr1_229567921_229567...               0
# chr14_90867735_90867756_+_chr1_151374008_151374...               0
# chr15_45003800_45003821_+_chr5_132010140_132010...               0
# chr15_75017771_75017794_-_chr11_116707103_11670...               0
# chr17_56316086_56316107_+_chr2_25384610_25384631_-               0
# chr17_65362517_65362538_-_chr22_50928166_509281...               0
# chr19_47735761_47735782_-_chr2_29072705_29072726_+               0
# chr1_11907159_11907180_-_chr4_70822060_70822081_-                0
# chr1_202888872_202888893_-_chr1_153946337_15394...               0
# chr21_27542874_27542895_-_chr8_82195590_82195611_+               0
# chr2_155555978_155555999_+_chr20_3596464_3596485_+               0
# chr3_150780776_150780797_+_chr17_61995273_61995...               0
# ...

# %%
df1[df1['JurkatI92_2.truth'] == 1]['fusion_key'].to_list()
# Out:
# ['HBG2>>GAPDHS',
#  'RP11-174G6.1>>ACTA1',
#  'CALM1>>PSMB4',
#  'B2M>>IL4',
#  'CYP1A1>>APOA1',
#  'LPO>>POMC',
#  'PSMD12>>MIOX',
#  'BBC3>>SPDYA',
#  'NPPA>>CSN2',
#  'KLHL12>>CREB3L4',
#  'APP>>FABP5',
#  'KCNJ3>>ATRN',
#  'CLRN1-AS1>>CSHL1,GH1',
#  'OPA1>>AVP',
#  'IL15>>IL21',
#  'TBC1D1>>CXADR',
#  'F13A1>>CTRC',
#  'NDUFA5>>EDDM3A']

# %%
df1[df1['PC9_5.truth'] == 1]
# Out:
#                                                     A549_1.7269246  \
# chr11_5275511_5275532_-_chr19_36034231_36034268_+                0
# chr12_14840875_14840896_+_chr1_229567921_229567...               0
# chr14_90867735_90867756_+_chr1_151374008_151374...               0
# chr15_45003800_45003821_+_chr5_132010140_132010...               0
# chr15_75017771_75017794_-_chr11_116707103_11670...               0
# chr17_56316086_56316107_+_chr2_25384610_25384631_-               0
# chr17_65362517_65362538_-_chr22_50928166_509281...               0
# chr19_47735761_47735782_-_chr2_29072705_29072726_+               0
# chr1_11907159_11907180_-_chr4_70822060_70822081_-                0
# chr1_202888872_202888893_-_chr1_153946337_15394...               0
# chr21_27542874_27542895_-_chr8_82195590_82195611_+               0
# chr2_155555978_155555999_+_chr20_3596464_3596485_+               0
# chr3_150780776_150780797_+_chr17_61995273_61995...               0
# ...

# %%
sum(df1['PC9_1.truth'] != df1['PC9_4.truth'])
# Out:
# 0
